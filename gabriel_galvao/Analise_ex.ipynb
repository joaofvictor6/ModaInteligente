# %% [markdown]
# #  Bem-vindo à Análise Exploratória dos Produtos de Vestuário!
#
# O objetivo aqui é explorar o *Fashion Clothing Products Dataset* para entender melhor as características dos produtos e como esses dados podem ser usados para criar um sistema de recomendação eficiente.

# %%
# Instalar a biblioteca kagglehub, caso não esteja instalada
# !pip install kagglehub

# Importando as bibliotecas necessárias
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo do seaborn
sns.set(style="whitegrid")

# Baixar o dataset diretamente do Kaggle
path = kagglehub.dataset_download("shivamb/fashion-clothing-products-catalog")

# Carregar o dataset baixado
dataset_path = f'{path}/myntra_products_catalog.csv'
df = pd.read_csv(dataset_path)

# %% [markdown]
# ## 🔍 Informações Básicas sobre o Dataset
#
# Antes de começarmos, vamos dar uma olhada nas informações básicas do dataset, como a quantidade de registros, colunas e tipos de dados.

# %%
# Exibir informações gerais sobre o dataset
df.info()

# Exibir as primeiras linhas do dataset
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   Description   12491 non-null  object
#  7   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 780.8+ KB
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# ...

# %% [markdown]
# ## 💸 Análise 1: Distribuição dos Preços dos Produtos
#
# A primeira análise que faremos é sobre a distribuição dos preços dos produtos. Isso nos ajudará a entender se há uma grande variação nos preços e se o dataset contém mais produtos de alto ou baixo valor.

# %%
# Distribuição dos Preços
plt.figure(figsize=(10, 6))
sns.histplot(df['Price (INR)'], bins=30, kde=True)
plt.title('Distribuição dos Preços dos Produtos (INR)', fontsize=14)
plt.xlabel('Preço (INR)', fontsize=12)
plt.ylabel('Frequência', fontsize=12)
plt.show()

# %% [markdown]
# **💡 Insights**: A distribuição de preços mostra que a maioria dos produtos tem preços mais acessíveis, mas também existem alguns produtos de alto valor, sugerindo uma oferta diversa para diferentes perfis de consumidores.

# %% [markdown]
# ## 👗👔 Análise 2: Distribuição dos Produtos por Gênero
#
# Agora, vamos explorar a distribuição dos produtos por gênero. Com isso, podemos ver se a coleção é predominantemente voltada para algum público em específico ou se há um equilíbrio entre os gêneros.

# %%
# Distribuição por Gênero
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=df)
plt.title('Distribuição dos Produtos por Gênero', fontsize=14)
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.show()

# %% [markdown]
# **💡 Insights**: Observamos que a maioria dos produtos é voltada para o público feminino, o que pode indicar um foco maior nesse segmento. No entanto, também há uma boa variedade de produtos masculinos e unissex.

# %% [markdown]
# ## 🏷️ Análise 3: As 10 Marcas Mais Frequentes
#
# Além de entender o público-alvo, é importante conhecer as marcas mais representadas na nossa base de dados. Vamos agora verificar quais são as 10 marcas mais frequentes e com mais produtos disponíveis.

# %%
# Marcas Mais Frequentes
plt.figure(figsize=(12, 6))
top_brands = df['ProductBrand'].value_counts().nlargest(10)
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title('Top 10 Marcas Mais Frequentes', fontsize=14)
plt.xlabel('Marca do Produto', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **💡 Insights**: As marcas mais frequentes incluem nomes populares como 'Roadster', 'HRX' e 'DressBerry'. Esse dado é útil para entender quais marcas estão mais presentes no catálogo e podem ser mais relevantes para o sistema de recomendação.

# %% [markdown]
# ## 📝 Conclusão
#
# Com essa análise exploratória inicial, já podemos entender melhor a diversidade de preços, a distribuição dos produtos por gênero, e quais marcas têm mais relevância no dataset. Essas informações são valiosas para alimentar o sistema de recomendação, garantindo que ele considere diferentes faixas de preço, públicos e preferências de marca.
